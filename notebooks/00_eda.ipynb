# %% [markdown]
# # Exploración de datos (CSV CBIS-DDSM)
#
# Carga los CSV en `src/data/raw/csv/` para inspección manual: descripciones de casos (calc/mass), metadatos DICOM, etc.
#
# **Prerrequisito:** haber descargado el dataset y colocar los CSV en esa ruta (no suelen versionarse en git).

# %%
# Solo pandas para tablas; las rutas son relativas a esta carpeta `notebooks/`.
import pandas as pd

# %%
# Casos con calcificaciones — partición test (descripción por caso).
calc_case_des_test = pd.read_csv('../src/data/raw/csv/calc_case_description_test_set.csv')
calc_case_des_test
# Out:
#     patient_id  breast density left or right breast image view  \
# 0      P_00038               2                 LEFT         CC
# 1      P_00038               2                 LEFT        MLO
# 2      P_00038               2                RIGHT         CC
# 3      P_00038               2                RIGHT         CC
# 4      P_00038               2                RIGHT        MLO
# ..         ...             ...                  ...        ...
# 321    P_02464               2                RIGHT        MLO
# 322    P_02498               4                RIGHT         CC
# 323    P_02498               4                RIGHT        MLO
# 324    P_02501               3                RIGHT         CC
# 325    P_02501               3                RIGHT        MLO
#
#      abnormality id abnormality type              calc type calc distribution  \
# 0                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# ...

# %%
# Calcificaciones — partición train.
calc_case_des_train = pd.read_csv('../src/data/raw/csv/calc_case_description_train_set.csv')
calc_case_des_train
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
# Metadatos DICOM: aquí se enlazan rutas de imagen con pacientes/series (usado en build_resnet18_manifest).
dicom_info = pd.read_csv('../src/data/raw/csv/dicom_info.csv')
dicom_info
# Out:
#                                                file_path  \
# 0      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4      CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# ...                                                  ...
# 10232  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.62798...
# 10233  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.82451...
# 10234  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24759...
# 10235  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.28513...
# 10236  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.28513...
#
#                                               image_path  AccessionNumber  \
# 0      CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1      CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# ...

# %%
# Masas — partición test.
mass_case_des_test = pd.read_csv('../src/data/raw/csv/mass_case_description_test_set.csv')
mass_case_des_test
# Out:
#     patient_id  breast_density left or right breast image view  \
# 0      P_00016               4                 LEFT         CC
# 1      P_00016               4                 LEFT        MLO
# 2      P_00017               2                 LEFT         CC
# 3      P_00017               2                 LEFT        MLO
# 4      P_00032               3                RIGHT         CC
# ..         ...             ...                  ...        ...
# 373    P_01825               2                RIGHT        MLO
# 374    P_01833               2                RIGHT        MLO
# 375    P_01865               2                 LEFT        MLO
# 376    P_01912               3                RIGHT         CC
# 377    P_01912               3                RIGHT        MLO
#
#      abnormality id abnormality type mass shape    mass margins  assessment  \
# 0                 1             mass  IRREGULAR      SPICULATED           5
# ...

# %%
# Masas — partición train.
mass_case_des_train = pd.read_csv('../src/data/raw/csv/mass_case_description_train_set.csv')
mass_case_des_train
# Out:
#      patient_id  breast_density left or right breast image view  \
# 0       P_00001               3                 LEFT         CC
# 1       P_00001               3                 LEFT        MLO
# 2       P_00004               3                 LEFT         CC
# 3       P_00004               3                 LEFT        MLO
# 4       P_00004               3                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 1313    P_02033               2                RIGHT        MLO
# 1314    P_02079               2                RIGHT         CC
# 1315    P_02079               2                RIGHT        MLO
# 1316    P_02092               2                 LEFT         CC
# 1317    P_02092               2                 LEFT        MLO
#
#       abnormality id abnormality type                          mass shape  \
# 0                  1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# ...

# %%
# Metadatos agregados del dataset (si disponible en tu copia de CBIS-DDSM).
meta = pd.read_csv('../src/data/raw/csv/meta.csv')
meta
# Out:
#                                       SeriesInstanceUID  \
# 0     1.3.6.1.4.1.9590.100.1.2.117041576511324414842...
# 1     1.3.6.1.4.1.9590.100.1.2.438738396107617880132...
# 2     1.3.6.1.4.1.9590.100.1.2.767416741131676463382...
# 3     1.3.6.1.4.1.9590.100.1.2.296931352612305599800...
# 4     1.3.6.1.4.1.9590.100.1.2.436657670120353100077...
# ...                                                 ...
# 6770  1.3.6.1.4.1.9590.100.1.2.424889390711092892018...
# 6771  1.3.6.1.4.1.9590.100.1.2.627433012114953458354...
# 6772  1.3.6.1.4.1.9590.100.1.2.250048723412722873040...
# 6773  1.3.6.1.4.1.9590.100.1.2.323173986211744534717...
# 6774  1.3.6.1.4.1.9590.100.1.2.880917484135960246153...
#
#                                        StudyInstanceUID Modality  \
# 0     1.3.6.1.4.1.9590.100.1.2.229361142710768138411...       MG
# 1     1.3.6.1.4.1.9590.100.1.2.195593486612988388325...       MG
# 2     1.3.6.1.4.1.9590.100.1.2.257901172612530623323...       MG
# ...
